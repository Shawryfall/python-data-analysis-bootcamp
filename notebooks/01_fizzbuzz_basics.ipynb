# %% [markdown]
# # FizzBuzz Basics in Python
#
# This notebook demonstrates the classic FizzBuzz problem, often used in programming interviews to test basic control flow and modulo arithmetic.

# %% [markdown]
# ## 1. Problem description
#
# For each integer from 1 to 100:
#
# - If the number is divisible by 3, print `fizz`
# - If the number is divisible by 5, print `buzz`
# - If the number is divisible by both 3 and 5, print `fizzbuzz`
# - Otherwise, print the number itself

# %% [markdown]
# ## 2. Simple loop implementation

# %%
for i in range(1, 101):
    if i % 15 == 0:
        print("fizzbuzz")
    elif i % 3 == 0:
        print("fizz")
    elif i % 5 == 0:
        print("buzz")
    else:
        print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# buzz

# %% [markdown]
# ## 3. Wrap FizzBuzz in a function
#
# Wrapping the logic in a function makes it reusable and easier to test.

# %%
def fizzbuzz(n: int) -> str:
    """Return 'fizz', 'buzz', 'fizzbuzz', or the number as a string."""
    if n % 15 == 0:
        return "fizzbuzz"
    elif n % 3 == 0:
        return "fizz"
    elif n % 5 == 0:
        return "buzz"
    else:
        return str(n)

# Quick check for the first 20 numbers
for i in range(1, 21):
    print(i, "->", fizzbuzz(i))
# Out:
# 1 -> 1
# 2 -> 2
# 3 -> fizz
# 4 -> 4
# 5 -> buzz
# 6 -> fizz
# 7 -> 7
# 8 -> 8
# 9 -> fizz
# 10 -> buzz
# 11 -> 11
# 12 -> fizz
# 13 -> 13
# 14 -> 14
# 15 -> fizzbuzz
# 16 -> 16
# 17 -> 17
# 18 -> fizz
# 19 -> 19
# 20 -> buzz

# %% [markdown]
# ## 4. Generating a list of FizzBuzz outputs
#
# Instead of printing, we can build a list. This is useful if we want to test or further process the results in code.

# %%
results = [fizzbuzz(i) for i in range(1, 101)]
results[:20]  # show the first 20 elements
# Out:
# ['1',
#  '2',
#  'fizz',
#  '4',
#  'buzz',
#  'fizz',
#  '7',
#  '8',
#  'fizz',
#  'buzz',
#  '11',
#  'fizz',
#  '13',
#  '14',
#  'fizzbuzz',
#  '16',
#  '17',
#  'fizz',
#  '19',
#  'buzz']

# %% [markdown]
# ## 5. Summary
#
# In this notebook we:
#
# - Explained the FizzBuzz problem
# - Implemented a simple loop-based solution
# - Encapsulated the logic in a reusable `fizzbuzz` function
# - Generated a list of FizzBuzz outputs for further use
